# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df = pd.read_csv('output_data/cities.csv')
df
# Out:
#     Unnamed: 0            City      Lat      Long  Max Temp  Humidity  \
# 0            0      bredasdorp -34.5322   20.0403    287.15        82
# 1            1    general roca -39.0333  -67.5833    297.15        59
# 2            2    punta arenas -53.1500  -70.9167    280.15        70
# 3            3      georgetown   5.4112  100.3354    303.15        79
# 4            4          avarua -21.2078 -159.7750    300.15        69
# 5            5         rikitea -23.1203 -134.9692    298.85        71
# 6            6           bluff -46.6000  168.3333    293.15        52
# 7            7       cape town -33.9258   18.4232    289.26        77
# 8            8       tuatapere -46.1333  167.6833    293.15        52
# 9            9            boda   4.3189   17.4695    294.25        90
# 10          10         jalingo   8.8833   11.3667    301.43        53
# 11          11      vila velha -20.3297  -40.2925    297.15        83
# 12          12    dawson creek  55.7666 -120.2362    284.15        35
# 13          13          ossora  59.2353  163.0719    274.15        93
# 14          14         barsovo  61.1667   73.1667    265.15        86
# 15          15           lampa -33.2833  -70.9000    290.93        87
# 16          16       singapore   1.2897  103.8501    305.15        51
# 17          17  saint-philippe -21.3585   55.7679    297.15        88
# 18          18           kapaa  22.0752 -159.3190    300.37        69
#
#     Cloudiness  Wind Speed Country        Date
# 0           33        5.66      ZA  1618886183
# 1          100        7.23      AR  1618886070
# 2           20        7.20      CL  1618885926
# 3           20        0.51      MY  1618886139
# 4           75        4.12      CK  1618886338
# 5            4        3.64      PF  1618886339
# 6            1        2.68      NZ  1618886340
# 7            0        3.60      ZA  1618886226
# 8           18        2.68      NZ  1618886341
# 9           96        1.27      CF  1618886342
# 10          99        2.45      NG  1618886342
# 11          75        3.60      BR  1618886343
# 12           1        4.12      CA  1618886343
# 13         100        3.47      RU  1618886344
# 14          90        6.00      RU  1618886344
# 15           1        3.60      CL  1618886345
# 16          75        1.54      SG  1618885805
# 17          90        1.03      RE  1618886345
# 18           1        5.14      US  1618886136

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
locations = df[['Lat', 'Long']].astype(float)
weight = df['Humidity'].astype(float)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=weight,
                                dissipating=False, max_intensity=100,
                                point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
locations_narrow = df[(df['Max Temp']<299.817) & (df['Max Temp']>294.261) & (df['Wind Speed']<10) & (df['Cloudiness']<80)]
locations_narrow[['Lat', 'Long']]
# Out:
#         Lat      Long
# 5  -23.1203 -134.9692
# 11 -20.3297  -40.2925

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
locations_narrow['Hotel Name']=''

target_coordinates = locations_narrow[['Lat', 'Long']]
target_radius = 5000
target_type = 'hotel'

params = {
    'radius': target_radius,
    'types' : target_type,
    'key' : g_key,
    'keyword' :'hotel'
}


for index, row in target_coordinates.iterrows():
    lat = row['Lat']
    lon = row['Long']
    params['location'] = f"{lat},{lon}"
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    name_address = requests.get(base_url, params=params).json()
    print(name_address)
    
    try:
        locations_narrow.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except:
        print('Problem')
# Out:
# /Users/robthompson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# Problem
# {'html_attributions': [], 'next_page_token': 'ATtYBwI3EZHmke2PvmxybJcWky4T5oorqLeS8QpReaIm-SFkP9InL4b142QShn2jFyW8q-1iccwIY3W1jtitQKFYYJ_RzSmUao8lr0EvOQ8xxcZSpoGvw-ArArZq8qQE5vBZL9wAR4p4x2Gfkb68Mc3di0M7_d6xMjCBXekXUZFW010LAylF_X5bgp-KquTpiV4hWe3t6ZPOsYLvHVkmom_BqbxzRvtKuCu61xsxwXQPjM7f7ptw-kp24mbws_F1W8eoA-geXPRyMqWFwoplvttGKLyc-5g4Cx5H-oB_HLvnqeFrHhbKZpsbH0w5OM1kPFfgafqJZ_YjhNDklerpDSGgwyq8JXlwzbhfBC2M1HIWroNViWOTr-7TPUjT-pIOWc_uOCET3vfa9EgLzXDtfZC3IBteY1cEP8AzNr4WZd5U1e_TK3Lg0ITtP6lUDaIVIzk', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -20.310606, 'lng': -40.2826805}, 'viewport': {'northeast': {'lat': -20.30931777010728, 'lng': -40.28127992010727}, 'southwest': {'lat': -20.31201742989272, 'lng': -40.28397957989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Hotel Senac Ilha do Boi', 'photos': [{'height': 3120, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100016235106386365825">Fabiana Tavares</a>'], 'photo_reference': 'ATtYBwLnxx8jv9oAUeIG4sKwxwIO6HXhuvTwTuZVYQY5JIHZGywdlZKYpXvT7FXF4qBkSd1QOvI03-0edguHrEH7HlxXuR5Gh-X39GtYVb-p84UYW2NKZ-p9EiCSmoN_puowScAwxmNl4pSpRlM6LrYgH4tODxEDmyz1buhDYbe-cn5pIuai', 'width': 4160}], 'place_id': 'ChIJf4-7jLsXuAAR8vepJaOVI-Q', 'plus_code': {'compound_code': 'MPQ8+QW Vitoria, Vitória - State of Espírito Santo, Brazil', 'global_code': '58FXMPQ8+QW'}, 'rating': 4.7, 'reference': 'ChIJf4-7jLsXuAAR8vepJaOVI-Q', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 2272, 'vicinity': 'R. Bráulio Macedo, 417 - Ilha do Boi, Vitória'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -20.3056956, 'lng': -40.2932905}, 'viewport': {'northeast': {'lat': -20.30432072010728, 'lng': -40.29197797010728}, 'southwest': {'lat': -20.30702037989272, 'lng': -40.29467762989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Sheraton Vitoria Hotel', 'opening_hours': {'open_now': True}, 'photos': [{'height': 519, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101099047835746251195">Sheraton</a>'], 'photo_reference': 'ATtYBwKYkWa7NXx4A3MDHGO2DlpBBUEdxr6BB1DtCUto-oY3RgoCnrWdNhjGZ_Avyt-gmqsL_G8iAqv7LlanSW1R0ndsbt4i6XgXA_umZNXPm4DVbwsfWTH1x-Klx0Z-KinaNblTTMdktzDyC2LGgC0uQCzDGJX0TmKGKVkclKHiYB4bRr3E', 'width': 923}], 'place_id': 'ChIJGdJV6MEXuAARk4d0cj0NH58', 'plus_code': {'compound_code': 'MPV4+PM Praia do Canto, Vitória - State of Espírito Santo, Brazil', 'global_code': '58FXMPV4+PM'}, 'rating': 4.6, 'reference': 'ChIJGdJV6MEXuAARk4d0cj0NH58', 'scope': 'GOOGLE', 'types': ['lodging', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 2813, 'vicinity': 'Av. Saturnino De Brito Avenue 217 - Praia do Canto, Vitória'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -20.3156731, 'lng': -40.29602550000001}, 'viewport': {'northeast': {'lat': -20.31453827010728, 'lng': -40.29459197010728}, 'southwest': {'lat': -20.31723792989272, 'lng': -40.29729162989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Golden Tulip Porto Vitória', 'opening_hours': {'open_now': True}, 'photos': [{'height': 1536, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101860542196722513378">Golden Tulip Porto Vitória</a>'], 'photo_reference': 'ATtYBwKWHoI9EeFzbkIXqZU6EDrDRGz9xPOiR_KEitL24dabrqThLRhgwCuenXyoyLjc86grA_aUWDDD-5me7X9WErrnVjdai0I_znmDWkfYzuIXWqm4YFXJtdvZomHQgrfpvvAr8Z51bAMpa4QuuXA7ptQAOqIikgxqQrpbl8i2QlQJG2tD', 'width': 2880}], 'place_id': 'ChIJUSiLi84XuAARLh0wte8QgzA', 'plus_code': {'compound_code': 'MPM3+PH Enseada do Suá, Vitória - State of Espírito Santo, Brazil', 'global_code': '58FXMPM3+PH'}, 'rating': 4.6, 'reference': 'ChIJUSiLi84XuAARLh0wte8QgzA', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 3791, 'vicinity': 'A ...
# /Users/robthompson/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
print(locations_narrow)
hotel_df = locations_narrow[['Lat', 'Long', 'Hotel Name', 'City', 'Country']]
print(hotel_df)
# Out:
#     Unnamed: 0        City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 5            5     rikitea -23.1203 -134.9692    298.85        71           4
# 11          11  vila velha -20.3297  -40.2925    297.15        83          75
#
#     Wind Speed Country        Date               Hotel Name
# 5         3.64      PF  1618886339
# 11        3.60      BR  1618886343  Hotel Senac Ilha do Boi
#         Lat      Long               Hotel Name        City Country
# 5  -23.1203 -134.9692                              rikitea      PF
# 11 -20.3297  -40.2925  Hotel Senac Ilha do Boi  vila velha      BR

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Long"]]
print(locations)
# Out:
#         Lat      Long
# 5  -23.1203 -134.9692
# 11 -20.3297  -40.2925

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
